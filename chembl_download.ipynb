# %%
from os.path import isfile

# %%
import numpy as np

# %%
import pandas as pd

# %%
from joblib import Parallel, delayed

# %%
# conda install -c chembl chembl_webresource_client
import chembl_webresource_client as chembl

# %%
from ChEMBL import get_chembl_id, chembl_to_data_frame

# %%
def get_dude_dataframe(dude_id):
    """Download list of active compounds for a DUDe id and return a DataFrame"""
    
    # blacklist Uniprot IDs - investigate those and move to dictionary
    blacklist = []
    
    if isfile('data/data_dude_%s.csv' % dude_id):
        return None
    
    # get Uniprot IDs associatet with DUDe
    # TODO: do we want to extend that?
    uniprot_map = {
        # Obsolete
        'P0A5Y6': 'P9WGR1',
        'P45351': 'P0CS13',
        'P96275': 'P9WIJ3',
        # Not mapping
        'P68404': 'P05771',
    }
    
    uniprot_ids = pd.read_csv('http://dude.docking.org/targets/%s/uniprot.txt' % dude_id, 
                              header=None, names=['uniprot_id']).uniprot_id
    uniprot_ids = uniprot_ids.replace(uniprot_map).tolist()
   
    

    if len(uniprot_ids) == 0:
        return None
    
    # get activities from ChEMBL (try 5 times, again ChEMBL is fussy)
    for _ in range(5):
        try:
            data = pd.concat(chembl_to_data_frame(uniprot_id) 
                             for uniprot_id in uniprot_ids
                             if uniprot_id not in blacklist
                            )
            break
        except ValueError as e:
            pass
    else:
        return None
    
    # Resolve SMILES for ChEMBL IDs locally (very slow with web services for large targets)
    chembl_smiles = pd.read_csv('chembl_24.smi.gz', sep='\t', header=None,names=['smiles', 'chembl_id'])
    data_full = data.set_index('chembl_id').join(chembl_smiles.set_index('chembl_id')).reset_index()
    
    data_full['dude_id'] = dude_id
    
    # for memory efficiency set appropriate dtypes
    cat_columns = ['dude_id', 
                   'chembl_id', 
                   'uniprot_id',
                   'units', 
                   'operator', 
                   'bioactivity_type',
                   'smiles'
                  ]
    for col in cat_columns:
        data_full[col] = data_full[col].astype('category')
    
    data_full.to_csv('data/data_dude_%s.csv' % dude_id)
    # return data_full

# %%
# %%time
data = get_dude_dataframe('kpcb')
# Out:
# CPU times: user 8.33 s, sys: 285 ms, total: 8.62 s
# Wall time: 9.28 s

# %%
dude_ids = ['lck', 'src', 'ada17', 'hivpr', 'mk14', 'mmp13', 'aa2ar', 'bace1', 'pparg', 'parp1', 'ace', 'thrb', 'cdk2', 'esr1', 'esr2', 'vgfr2', 'fnta', 'drd3', 'csf1r', 'dhi1', 'casp3', 'gria2', 'kit', 'dyr', 'braf', 'tryb1', 'hdac8', 'aldr', 'akt1', 'ital', 'kpcb', 'tysy', 'ppard', 'hivint', 'ppara', 'urok', 'wee1', 'reni', 'grik1', 'aces', 'fa10', 'dpp4', 'adrb2', 'jak2', 'hivrt', 'fkb1a', 'cah2', 'kif11', 'try1', 'adrb1', 'akt2', 'rock1', 'pa2ga', 'pygm', 'mapk2', 'fa7', 'tgfr1', 'mk10', 'fak1', 'gcr', 'hdac2', 'prgr', 'ptn1', 'nram', 'abl1', 'hs90a', 'egfr', 'hxk4', 'mk01', 'cxcr4', 'lkha4', 'ada', 'pur2', 'pnph', 'andr', 'rxra', 'fpps', 'cp3a4', 'met', 'ampc', 'mp2k1', 'pyrd', 'pgh1', 'kith', 'thb', 'comt', 'cp2c9', 'aofb', 'fabp4', 'mcr', 'inha', 'pgh2', 'def', 'xiap', 'glcm', 'pde5a', 'nos1', 'sahh', 'hmdh', 'igf1r', 'plk1', 'fgfr1']

# %%
# %%time
# We need to run this few times, as some errors araise, I guess we are hitting some limits on ChEMBL there...
out = Parallel(n_jobs=-1, verbose=1)(delayed(get_dude_dataframe)(dude_id) for dude_id in dude_ids)
# data = pd.concat(out)
# Out:
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.5min
# Error when retrieving url: https://www.ebi.ac.uk/chemblws/targets/uniprot/P07700.json, status code: 404, msg: Target not found for accession:P07700
# Error when retrieving url: https://www.ebi.ac.uk/chemblws/targets/uniprot/Q9TT96.json, status code: 404, msg: Target not found for accession:Q9TT96
# Error when retrieving url: https://www.ebi.ac.uk/chemblws/targets/uniprot/P56519.json, status code: 404, msg: Target not found for accession:P56519
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed:  3.9min finished
# CPU times: user 604 ms, sys: 122 ms, total: 725 ms
# Wall time: 3min 55s

# %% [markdown]
# # Read master DataFrame with all data

# %%
data = pd.concat(pd.read_csv('data/data_dude_%s.csv' % dude_id, index_col=0) for dude_id in dude_ids)
cat_columns = ['dude_id', 
               'chembl_id', 
               'uniprot_id',
               'units', 
               'operator', 
               'bioactivity_type',
               'smiles'
              ]
for col in cat_columns:
    data[col] = data[col].astype('category')
data['value'] = data['value'].astype(float)

# %%
len(data)
# Out:
# 642030

# %%
data.dtypes
# Out:
# chembl_id           category
# uniprot_id          category
# bioactivity_type    category
# operator            category
# value                float64
# units               category
# smiles              category
# dude_id             category
# dtype: object

# %%
data.sort_values('value')
# Out:
#            chembl_id uniprot_id bioactivity_type operator         value  \
# 6357    CHEMBL321397     P06536      Weight gain        = -2.360000e+02
# 6342    CHEMBL320320     P06536      Weight gain        = -2.240000e+02
# 547    CHEMBL1643626     P27487       Inhibition        = -2.022000e+02
# 390     CHEMBL113032     P06536      Weight gain        = -1.860000e+02
# 339     CHEMBL109690     P06536      Weight gain        = -1.800000e+02
# 395     CHEMBL113561     P06536      Weight gain        = -1.450000e+02
# 341     CHEMBL109690     P06536      Weight gain        = -1.400000e+02
# 6339    CHEMBL320320     P06536      Weight gain        = -1.290000e+02
# 6354    CHEMBL321397     P06536      Weight gain        = -1.270000e+02
# 6402    CHEMBL306894     P35354       Inhibition        = -1.250000e+02
# 11330    CHEMBL67324     P35354       Inhibition        = -1.250000e+02
# 797        CHEMBL135     Q62986           Weight        = -1.212000e+02
# 1383       CHEMBL135     P06211           Weight        = -1.212000e+02
# 11847      CHEMBL691     P06211           Weight        = -1.202000e+02
# 1244      CHEMBL1405     Q62986           Weight        = -1.202000e+02
# 1675      CHEMBL1405     P06211           Weight        = -1.202000e+02
# 8760       CHEMBL691     Q62986           Weight        = -1.202000e+02
# 11048   CHEMBL497906     P03372         Activity        = -1.110000e+02
# 6270   CHEMBL3746293     Q16539       Inhibition        = -1.097000e+02
# 7928     CHEMBL35063     P35355           Change        = -1.000000e+02
# 4176    CHEMBL388978     P24941       Inhibition        = -1.000000e+02
# 6223     CHEMBL35063     Q63921           Change        = -1.000000e+02
# 8596     CHEMBL37599     P35355           Change        = -1.000000e+02
# 6401    CHEMBL306894     P35354       Inhibition        = -1.000000e+02
# 5740    CHEMBL284477     P35355           Change        = -1.000000e+02
# 6802     CHEMBL37599     Q63921           Change        = -1.000000e+02
# 4479    CHEMBL284477     Q63921           Change        = -1.000000e+02
# 11739  CHEMBL3581570     P22303       Inhibition        = -1.000000e+02
# 11745  CHEMBL3581581     P22303       Inhibition        = -1.000000e+02
# 11740  CHEMBL3581571     P22303       Inhibition        = -1.000000e+02
# ...              ...        ...              ...      ...           ...
# 6939     CHEMBL48180     Q72874               Ki        =  1.995262e+17
# 7003     CHEMBL51463     Q72874               Ki        =  1.995262e+17
# 3626    CHEMBL299376     Q72874               Ki        =  1.995262e+17
# 6970     CHEMBL49288     Q72874               Ki        =  2.041738e+17
# 3624    CHEMBL299375     Q72874               Ki        =  2.691535e+17
# 3666    CHEMBL300858     Q72874               Ki        =  2.951209e+17
# 2731    CHEMBL298006     P19643               Ki        =  3.311311e+17
# 7013     CHEMBL52051     Q72874               Ki        =  3.467369e+17
# 7004     CHEMBL51463     Q72874               Ki        =  3.715352e+17
# 6252    CHEMBL408723     Q72874               Ki        =  4.570882e+17
# 3600    CHEMBL298303     Q72874               Ki        =  4.786301e+17
# 3680    CHEMBL301365     Q72874               Ki        =  7.079458e+17
# 4827    CHEMBL424940     P56560             IC50        =  1.000000e+18
# 7014     CHEMBL52130     Q72874               Ki        =  1.000000e+18
# 609     CHEMBL120070     P00918             IC50        =  1.122018e+18
# 590     CHEMBL120018     P00918             IC50        =  1.230269e+18
# 4932     CHEMBL45069     P19643               Ki        =  1.318257e+18
# 655     CHEMBL121291     P00918             IC50        =  1.621810e+18
# 6907     CHEMBL46337     Q72874               Ki        =  1.659587e+18
# 3669    CHEMBL300968     Q72874               Ki        =  2.630268e+18
# 3513    CHEMBL295414     Q72874               Ki        =  2.951209e+18
# 3645    CHEMBL300050     Q72874               Ki        =  4.168694e+18
# 6944     CHEMBL48565     Q72874               Ki        =  4.570882e+18
# 1809    CHEMBL174847     P00918               Ki        =  4.570882e+18
# 3636    CHEMBL299659     Q72874               Ki        =  4.570882e+18
# 387        CHEMBL114     Q72874               Ki        =  8.317638e+18
# 7393    CHEMBL358263     P00918               Ki        =  1.862087e+19
# 1220    CHEMBL148660     P00918               Ki        =  3.981072e+19
# 1247    CHEMBL150043     P00918               Ki        =  2.089296e+20
# 8770    CHEMBL444536     P00918               Ki        =  1.202264e+21
#
#              units                                             smiles dude_id
# 6357   Unspecified  C12(C(=O)N(C(=O)N(C1=O)C)C)O[C@@H]1C(=CC2)[C@@...     gcr
# 6342   Unspecified  C12(C(=O)c3c(C1=O)cccc3)O[C@@H]1C(=CC2)[C@@]2(...     gcr
# 547              %        C(CCCCCCC)c1c(CCCCCCCC(=O)ONN)nc2c(n1)cccc2    dpp4
# 390    Unspecified  c12n(ncc1C[C@@]1(C3=CCCC([C@H]3CCC1=C2)(C(=O)O...     gcr
# 339    Unspecified  C12(C(=O)NC(=O)NC1=O)O[C@@H]1C(=CC2)[C@@]2(C(=...     gcr
# 395    Unspecified  c12n(ncc1C[C@@]1(C3=CC[C@]4(C([C@@H]3CCC1=C2)C...     gcr
# 341    Unspecified  C12(C(=O)NC(=O)NC1=O)O[C@@H]1C(=CC2)[C@@]2(C(=...     gcr
# 6339   Unspecified  C12(C(=O)c3c(C1=O)cccc3)O[C@@H]1C(=CC2)[C@@]2(...     gcr
# 6354   Unspecified  C12(C(=O)N(C(=O)N(C1=O)C)C)O[C@@H]1C(=CC2)[C@@...     gcr
# 6402             %  n1(c(cc(n1)CO[N+](=O)[O-])c1ccc(S(=O)(=O)C)cc1...    pgh2
# 11330            %         n1(c(cc(n1)CO)c1ccc(S(=O)(=O)C)cc1)C1CCCC1    pgh2
# 797             mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr2
# 1383            mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr1
# 11847           mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr1
# 1244            mg  [C@@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC...    esr2
# 1675            mg  [C@@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC...    esr1
# 8760            mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr2
# 11048            %             C=C([C@@H](NC(=O)c1occc1)c1ccccc1)CCCC    esr1
# 6270             %  c1(ccc(c(c1C)NC(=O)c1sc2c(c1)cccc2)F)c1n[nH]c(...    mk14
# 7928             %    C\1(=C\c2cc(c(OC(=O)C)cc2)OC)/c2c(c(ccn2)C)CCC1    pgh2
# 4176             %  [C@@]12(n3c4c5n([C@H](O1)C[C@H]([C@H]2OC)NC)c1...    cdk2
# 6223             %    C\1(=C\c2cc(c(OC(=O)C)cc2)OC)/c2c(c(ccn2)C)CCC1    pgh1
# 8596             %   n1c2/C(=C/c3cc(c(OC(=O)C)cc3)OC)/CCCc2cc2c1cccc2    pgh2
# 6401             %  n1(c(cc(n1)CO[N+](=O)[O-])c1ccc(S(=O)(=O)C)cc1...    pgh2
# 5740             %                C\1(=C\c2ccc(cc2)C)/c2ncc(cc2CCC1)C    pgh2
# 6802             %   n1c2/C(=C/c3cc(c(OC(=O)C)cc3)OC)/CCCc2cc2c1cccc2    pgh1
# 4479             %                C\1(=C\c2ccc(cc2)C)/c2ncc(cc2CCC1)C    pgh1
# 11739            %  [C@@H]1(C[C@@]2(C(=O)[C@@](C(=O)[C@@H]3[C@@]1(...    aces
# 11745            %  [C@@H]1(C[C@@]2(C(=O)[C@@](C(=O)[C@H]([C@@]1(C...    aces
# 11740            %  CC1(C)[C@@H]2[C@]3(C(=O)[C@]4(C(=O)[C@](C[C@H]...    aces
# ...            ...                                                ...     ...
# 6939            nM  C(=O)([C@@H]([C@H]([C@@H]([C@@H](NC(=O)OCc1ccc...   hivpr
# 7003            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 3626            nM  [C@H](C(=O)N[C@H](C(=O)NCc1ncccc1)[C@H](CC)C)(...   hivpr
# 6970            nM  C(=O)(N[C@H]([C@H]([C@@H](CC(=O)[C@H](NC(=O)OC...   hivpr
# 3624            nM  C(=O)(N[C@H]([C@H]([C@@H](CC(=O)[C@H](NC(=O)OC...   hivpr
# 3666            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)[C@...   hivpr
# 2731            nM                      c1(n(c2c(c1)cccc2)C)CN(CC#C)C    aofb
# 7013            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)NCc1ncccc1)C(C...   hivpr
# 7004            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 6252            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ncccc1)C(C...   hivpr
# 3600            nM  C(=O)([C@@H](NC(=O)[C@H](CC(=O)N)NC(=O)OCc1ccc...   hivpr
# 3680            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 4827            nM                  c1c(ccc(c1)c1cc([nH]n1)c1ccccc1)C    aofb
# 7014            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)CNC(=O)OCc1ccc...   hivpr
# 609             nM                      S(=O)(=O)(c1sc(Sc2sccc2)cc1)N    cah2
# 590             nM              S(=O)(=O)(c1sc(S(=O)(=O)N)cc1)c1sccc1    cah2
# 4932            nM             c1(ccc2c(c1)cc([nH]2)CNCC#C)OCc1ccccc1    aofb
# 655             nM    S(=O)(=O)(c1ccc(N2C(=O)CCC2)c([N+](=O)[O-])c1)N    cah2
# 6907            nM  C(=O)(N[C@H](C(=O)OC)Cc1ccccc1)[C@@H](NC(=O)[C...   hivpr
# 3669            nM  C(=O)(N[C@H]([C@@H]([C@H]([C@@H](NC(=O)[C@@H](...   hivpr
# 3513            nM  N(C1c2c(C[C@H]1O)cccc2)C(=O)C(C[C@@H]([C@@H](N...   hivpr
# 3645            nM  C(=O)(N[C@H](C(=O)OC)C(C)C)[C@@H](NC(=O)[C@@H]...   hivpr
# 6944            nM  C(=O)(N[C@H]([C@H]([C@H]([C@@H](NC(=O)[C@@H](N...   hivpr
# 1809            nM                           S(=O)(=O)(c1ccc(NC)cc1)N    cah2
# 3636            nM  C(=O)(N[C@H]([C@H]([C@@H]([C@@H](NC(=O)OCc1ccc...   hivpr
# 387             nM  c1ccc2c(c1)nc(cc2)C(=O)N[C@H](C(=O)N[C@H]([C@@...   hivpr
# 7393            nM                             c1cc(ccc1S(=O)(=O)N)CC    cah2
# 1220            nM                          S(=O)(=O)(c1ccc(cc1)CCC)N    cah2
# 1247            nM                         S(=O)(=O)(c1ccc(cc1)CCCC)N    cah2
# 8770            nM                        S(=O)(=O)(c1ccc(cc1)CCCCC)N    cah2
#
# [642030 rows x 8 columns]

# %%
data.bioactivity_type.unique()
# Out:
# [Residual Activity, Ki, Kd, Inhibition, IC50, ..., Release, Activity remaining, cholesterol level, Suppression, PPB]
# Length: 500
# Categories (500, object): [Residual Activity, Ki, Kd, Inhibition, ..., Activity remaining, cholesterol level, Suppression, PPB]

# %%
data.units.unique()
# Out:
# [%, nM, ug.mL-1, mg.kg-1, M, ..., 1/minute, uM mg-1, mg dl-1, dpm, nM/s]
# Length: 238
# Categories (238, object): [%, nM, ug.mL-1, mg.kg-1, ..., uM mg-1, mg dl-1, dpm, nM/s]

# %%
data.value.describe()
# Out:
# count    6.420300e+05
# mean     2.362975e+15
# std      1.524019e+18
# min     -2.360000e+02
# 25%      2.800000e+01
# 50%      6.309600e+02
# 75%      1.000000e+04
# max      1.202264e+21
# Name: value, dtype: float64

# %%
data.groupby('dude_id')['chembl_id'].nunique().sort_values()
# Out:
# dude_id
# def         70
# pur2       173
# fabp4      229
# comt       282
# tryb1      288
# fpps       299
# sahh       307
# pnph       381
# inha       438
# kith       441
# nram       445
# ada        488
# ital       535
# wee1       541
# pa2ga      544
# fa7        582
# cxcr4      615
# fkb1a      684
# lkha4      693
# grik1      705
# pygm       854
# kif11     1058
# pyrd      1070
# hxk4      1122
# hmdh      1123
# tgfr1     1163
# rxra      1217
# xiap      1230
# mcr       1276
# tysy      1438
#          ...
# aofb      4344
# adrb2     4652
# dpp4      4727
# akt1      4738
# jak2      5265
# met       5296
# hivpr     5333
# pparg     5350
# drd3      5801
# mk14      5863
# esr1      5970
# src       6140
# cah2      6189
# thb       6287
# pgh1      6590
# bace1     6665
# fa10      6761
# andr      6797
# pgh2      7218
# egfr      8509
# aa2ar     8650
# thrb      8994
# vgfr2     9301
# aces     10429
# glcm     12116
# cp2c9    12401
# mk01     16799
# cp3a4    19134
# plk1     25643
# ampc     62235
# Name: chembl_id, Length: 102, dtype: int64

# %%
data['pvalue'] = (-np.log10(data['value']) + 9)
# Out:
# /home/maciek/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in log10
#   if __name__ == '__main__':

# %%
data
# Out:
#          chembl_id uniprot_id   bioactivity_type operator       value  \
# 0         CHEMBL10     P06239  Residual Activity        =       32.00
# 1         CHEMBL10     P06239  Residual Activity        =       91.00
# 2         CHEMBL10     P06239  Residual Activity        =       27.00
# 3         CHEMBL10     P06239  Residual Activity        =       79.00
# 4         CHEMBL10     P06239                 Ki        =     5011.87
# 5         CHEMBL10     P06239                 Kd        =     2800.00
# 6         CHEMBL10     P06239         Inhibition        =       32.00
# 7         CHEMBL10     P06239                 Kd        =     2800.00
# 8         CHEMBL10     P06239         Inhibition        =       68.00
# 9         CHEMBL10     P06239         Inhibition        =       55.00
# 10        CHEMBL10     P06239               IC50        =     3450.00
# 11        CHEMBL10     P06240           Activity        =       56.00
# 12    CHEMBL100016     P06239               IC50        =   234000.00
# 13    CHEMBL100446     P06239               IC50        =    65000.00
# 14    CHEMBL100553     P06239               IC50        >  2030000.00
# 15    CHEMBL100577     P06239               IC50        >  2030000.00
# 16    CHEMBL100650     P06239               IC50        >  2030000.00
# 17    CHEMBL100687     P06239               IC50        >  2030000.00
# 18      CHEMBL1009     P06239               IC50        =     3729.00
# 19    CHEMBL100922     P06239               IC50        =   203000.00
# 20    CHEMBL101078     P06239               IC50        =   487000.00
# 21    CHEMBL101253     P06239                 Ki        >     5011.87
# 22    CHEMBL101253     P06239                 Kd        >    10000.00
# 23    CHEMBL101253     P06239                 Kd        >    10000.00
# 24    CHEMBL101311     P06239                 Ki        =      199.53
# 25    CHEMBL101337     P06239               IC50        >  2030000.00
# 26    CHEMBL101506     P06239               IC50        =   193000.00
# 27    CHEMBL101659     P06239               IC50        =    16000.00
# 28    CHEMBL101683     P06239  Residual Activity        =       49.00
# 29    CHEMBL101683     P06239  Residual Activity        =       83.00
# ...            ...        ...                ...      ...         ...
# 4405   CHEMBL91730     P11362  Residual Activity        =       40.00
# 4406   CHEMBL91730     P11362  Residual Activity        =      127.00
# 4407   CHEMBL91815     P11362               IC50        =      880.00
# 4408   CHEMBL91829     P11362                 Kd        >    10000.00
# 4409   CHEMBL91829     P11362                 Kd        >    10000.00
# 4410   CHEMBL91829     P11362                 Kd        =     5100.00
# 4411   CHEMBL92361     P11362           Activity        =       80.00
# 4412   CHEMBL92361     P11362         Inhibition        =       32.00
# 4413   CHEMBL92461     P11362  Residual Activity        =      104.00
# 4414   CHEMBL92461     P11362  Residual Activity        =      117.00
# 4415     CHEMBL939     P11362                 Kd        >    10000.00
# 4416     CHEMBL939     P11362                 Ki        >     3981.07
# 4417     CHEMBL939     P11362                 Ki        >     3981.07
# 4418     CHEMBL939     P11362                 Kd        >    10000.00
# 4419     CHEMBL941     P11362                 Kd        >    10000.00
# 4420     CHEMBL941     P11362                 Ki        >     3981.07
# 4421     CHEMBL941     P11362                 Kd        >    10000.00
# 4422     CHEMBL941     P11362           Activity        =       80.00
# 4423   CHEMBL95207     P11362         Inhibition        =       -0.33
# 4424   CHEMBL95207     P11362         Inhibition        =       -2.26
# 4425   CHEMBL95502     P11362         Inhibition        =        6.46
# 4426   CHEMBL95502     P11362         Inhibition        =        1.68
# 4427   CHEMBL95692     P11362                 Ki        >     5011.87
# 4428   CHEMBL97771     P11362  Residual Activity        =       48.00
# 4429   CHEMBL97771     P11362  Residual Activity        =       62.00
# 4430   CHEMBL98350     P11362  Residual Activity        =       81.00
# 4431   CHEMBL98350     P11362  Residual Activity        =      107.00
# 4432   CHEMBL98385     P11362        Selectivity        =      600.00
# 4433   CHEMBL98538     P11362        Selectivity        =      164.00
# 4434   CHEMBL98633     P11362        Selectivity        =       72.00
#
#             units                                             smiles dude_id  \
# 0               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 1               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 2               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 3               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 4              nM  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 5              nM  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 6               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 7              nM  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 8               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 9               %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 10             nM  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 11              %  [nH]1c(c(nc1c1ccc([S+]([O-])C)cc1)c1ccc(cc1)F)...     lck
# 12             nM                      C(=C\c1cc(O)ccc1)/c1cc(O)ccc1     lck
# 13             nM            c1(cc(c2cc3c(cc2)c(ccc3O)O)ccc1O)C(=O)O     lck
# 14             nM  C(=C\c1ccc(OCc2ccccc2)cc1)/c1cc(cc(OCc2ccccc2)...     lck
# 15             nM  c1(c(OCc2ccccc2)ccc(/C=C/c2ccc(OCc3ccccc3)cc2)...     lck
# 16             nM  C(=C\c1cc(OCc2ccccc2)ccc1)/c1cc(cc(OCc2ccccc2)...     lck
# 17             nM    C(=C\c1ccccc1)/c1cc(cc(OCc2ccccc2)c1)OCc1ccccc1     lck
# 18             nM                      N[C@H](C(=O)O)Cc1ccc(c(c1)O)O     lck
# 19             nM                      c1(c(ccc(c1)/C=C/c1ccccc1)O)O     lck
# 20             nM                     c1c(cc(cc1O)CCc1cc(cc(c1)O)O)O     lck
# 21             nM             Clc1ccc(Nc2nnc(c3c2cccc3)Cc2ccncc2)cc1     lck
# 22             nM             Clc1ccc(Nc2nnc(c3c2cccc3)Cc2ccncc2)cc1     lck
# 23             nM             Clc1ccc(Nc2nnc(c3c2cccc3)Cc2ccncc2)cc1     lck
# 24             nM   n1c(nccc1Nc1cc(ccc1Cl)Cl)Nc1ccc(OCC(CN(C)C)O)cc1     lck
# 25             nM    c1(c(OCc2ccccc2)ccc(/C=C/c2ccccc2)c1)OCc1ccccc1     lck
# 26             nM                      c1(cc(cc(c1)/C=C/c1ccccc1)O)O     lck
# 27             nM                C(=C\c1cc(cc(c1)O)O)/c1cc(cc(c1)O)O     lck
# 28              %             Clc1ccc(cc1)NC(=O)c1c(cccc1)NCc1ccncc1     lck
# 29              %             Clc1ccc(cc1)NC(=O)c1c(cccc1)NCc1ccncc1     lck
# ...           ...                                                ...     ...
# 4405            %      c1(c(n(nc1c1ccncc1)c1ccc(cc1)Cl)O)c1ccc(cc1)F   fgfr1
# 4406            %      c1(c(n(nc1c1ccncc1)c1ccc(cc1)Cl)O)c1ccc(cc1)F   fgfr1
# 4407           nM  c1(c(c2c([nH]1)CCCC2)CCC(=O)O)/C=C/1\C(=O)Nc2c...   fgfr1
# 4408           nM  C12=C(c3cn(c4c3cccc4)CC[C@H](OCCn3cc1c1c3cccc1...   fgfr1
# 4409           nM  C12=C(c3cn(c4c3cccc4)CC[C@H](OCCn3cc1c1c3cccc1...   fgfr1
# 4410           nM  C12=C(c3cn(c4c3cccc4)CC[C@H](OCCn3cc1c1c3cccc1...   fgfr1
# 4411            %            OC(=O)Cc1c2[nH]c(=O)c3ccccc3n2c2c1cccc2   fgfr1
# 4412            %            OC(=O)Cc1c2[nH]c(=O)c3ccccc3n2c2c1cccc2   fgfr1
# 4413            %               n1cc(cn2c1c(cn2)c1cscc1)c1ccc(cc1)OC   fgfr1
# 4414            %               n1cc(cn2c1c(cn2)c1cscc1)c1ccc(cc1)OC   fgfr1
# 4415           nM  C1COCCN1CCCOc1c(cc2c(c1)c(ncn2)Nc1cc(Cl)c(F)cc...   fgfr1
# 4416           nM  C1COCCN1CCCOc1c(cc2c(c1)c(ncn2)Nc1cc(Cl)c(F)cc...   fgfr1
# 4417           nM  C1COCCN1CCCOc1c(cc2c(c1)c(ncn2)Nc1cc(Cl)c(F)cc...   fgfr1
# 4418           nM  C1COCCN1CCCOc1c(cc2c(c1)c(ncn2)Nc1cc(Cl)c(F)cc...   fgfr1
# 4419           nM  c1(nc(c2cnccc2)ccn1)Nc1cc(NC(=O)c2ccc(CN3CCN(C...   fgfr1
# 4420           nM  c1(nc(c2cnccc2)ccn1)Nc1cc(NC(=O)c2ccc(CN3CCN(C...   fgfr1
# 4421           nM  c1(nc(c2cnccc2)ccn1)Nc1cc(NC(=O)c2ccc(CN3CCN(C...   fgfr1
# 4422            %  c1(nc(c2cnccc2)ccn1)Nc1cc(NC(=O)c2ccc(CN3CCN(C...   fgfr1
# 4423            %         CN1CCC(CC1)n1cnc(c1c1ccnc(N)n1)c1ccc(F)cc1   fgfr1
# 4424            %         CN1CCC(CC1)n1cnc(c1c1ccnc(N)n1)c1ccc(F)cc1   fgfr1
# 4425            %  CC1(C)CC(CC(C)(C)N1)n1cnc(c1c1ccnc(N)n1)c1ccc(...   fgfr1
# 4426            %  CC1(C)CC(CC(C)(C)N1)n1cnc(c1c1ccnc(N)n1)c1ccc(...   fgfr1
# 4427           nM         c1nc(c(n1C1CCNCC1)c1nc(ncc1)OC)c1ccc(cc1)F   fgfr1
# 4428            %       c1(ccc(cc1)Oc1ccccc1)Nc1c2cc(c(cc2ncn1)OC)OC   fgfr1
# 4429            %       c1(ccc(cc1)Oc1ccccc1)Nc1c2cc(c(cc2ncn1)OC)OC   fgfr1
# 4430            %               o1c2c(c(=O)cc1N1CCOCC1)cccc2c1ccccc1   fgfr1
# 4431            %               o1c2c(c(=O)cc1N1CCOCC1)cccc2c1ccccc1   fgfr1
# 4432  Unspecified                    c1(sc(cn1)c1ccccc1)Nc1nc(ccc1)C   fgfr1
# 4433  Unspecified                       c1(sc(cn1)c1ccccc1)Nc1ncccc1   fgfr1
# 4434  Unspecified                  c1(NC(=O)c2ccccc2)sc(cn1)c1ccccc1   fgfr1
#
#         pvalue
# 0     7.494850
# 1     7.040959
# 2     7.568636
# 3     7.102373
# 4     5.300000
# 5     5.552842
# 6     7.494850
# 7     5.552842
# 8     7.167491
# 9     7.259637
# 10    5.462181
# 11    7.251812
# 12    3.630784
# 13    4.187087
# 14    2.692504
# 15    2.692504
# 16    2.692504
# 17    2.692504
# 18    5.428408
# 19    3.692504
# 20    3.312471
# 21    5.300000
# 22    5.000000
# 23    5.000000
# 24    6.699992
# 25    2.692504
# 26    3.714443
# 27    4.795880
# 28    7.309804
# 29    7.080922
# ...        ...
# 4405  7.397940
# 4406  6.896196
# 4407  6.055517
# 4408  5.000000
# 4409  5.000000
# 4410  5.292430
# 4411  7.096910
# 4412  7.494850
# 4413  6.982967
# 4414  6.931814
# 4415  5.000000
# 4416  5.400000
# 4417  5.400000
# 4418  5.000000
# 4419  5.000000
# 4420  5.400000
# 4421  5.000000
# 4422  7.096910
# 4423       NaN
# 4424       NaN
# 4425  8.189767
# 4426  8.774691
# 4427  5.300000
# 4428  7.318759
# 4429  7.207608
# 4430  7.091515
# 4431  6.970616
# 4432  6.221849
# 4433  6.785156
# 4434  7.142668
#
# [642030 rows x 9 columns]

# %%
data.query('bioactivity_type in ["Ki", "Kd", "EC50", "IC50"] and pvalue > 6').sort_values('value')
# Out:
#            chembl_id uniprot_id bioactivity_type operator         value  \
# 5501     CHEMBL34259     P00381             IC50        =  3.300000e-12
# 771    CHEMBL1790497     P00797             IC50        =  2.600000e-10
# 6546    CHEMBL428862     P00375               Ki        =  5.230000e-09
# 5366     CHEMBL34259     P00375               Ki        =  5.620000e-09
# 3274    CHEMBL267104     P00381             IC50        =  1.000000e-08
# 1151    CHEMBL267104     P00469             IC50        =  1.200000e-07
# 682     CHEMBL157187     P34971               Kd        =  3.200000e-07
# 2423    CHEMBL157187     P18762               Kd        =  3.200000e-07
# 6304    CHEMBL423055     P18762               Kd        =  4.700000e-07
# 2437    CHEMBL423055     P34971               Kd        =  4.700000e-07
# 243    CHEMBL2368596     P56658               Ki        =  1.500000e-06
# 6033    CHEMBL379921     Q72874               Ki        =  6.000000e-06
# 650     CHEMBL354666     P03468             IC50        =  1.000000e-05
# 713     CHEMBL160277     P34971               Kd        =  1.000000e-05
# 2580    CHEMBL160277     P18762               Kd        =  1.000000e-05
# 1096     CHEMBL98906     P03468             IC50        =  1.000000e-05
# 6686    CHEMBL433973     Q72874               Ki        =  1.400000e-05
# 4052    CHEMBL297088     P00374               Ki        =  1.400000e-05
# 2291    CHEMBL206031     Q72874               Ki        =  1.500000e-05
# 0       CHEMBL117353     Q64737               Ki        =  1.900000e-05
# 552       CHEMBL1560     P12822             IC50        =  2.700000e-05
# 10062  CHEMBL3314093     P22303               Kd        =  3.300000e-05
# 10061  CHEMBL3314092     P22303               Kd        =  3.600000e-05
# 634     CHEMBL353683     P03468             IC50        =  4.000000e-05
# 5528    CHEMBL355306     Q72874               Ki        =  4.800000e-05
# 1051   CHEMBL1813006     Q07869             EC50        =  5.000000e-05
# 76      CHEMBL279302     P22102             IC50        =  5.000000e-05
# 5480    CHEMBL353288     Q72874               Ki        =  5.400000e-05
# 5815    CHEMBL367454     Q72874               Ki        =  5.800000e-05
# 1049   CHEMBL1813005     Q07869             EC50        =  6.000000e-05
# ...              ...        ...              ...      ...           ...
# 9206    CHEMBL463865     P56817             IC50        =  9.980000e+02
# 7367    CHEMBL487431     Q16539             IC50        =  9.980000e+02
# 4504   CHEMBL3645106     O60674             IC50        =  9.989200e+02
# 1613   CHEMBL3668019     P36897             IC50        =  9.989900e+02
# 402    CHEMBL1421255     P42574             IC50        =  9.990000e+02
# 956    CHEMBL2062811     Q05397             IC50        =  9.990000e+02
# 1764   CHEMBL3642399     Q05397             IC50        =  9.990000e+02
# 1663   CHEMBL3642295     Q05397             IC50        =  9.990000e+02
# 1709   CHEMBL3642344     Q05397             IC50        =  9.990000e+02
# 1740   CHEMBL3642375     Q05397             IC50        =  9.990000e+02
# 1757   CHEMBL3642392     Q05397             IC50        =  9.990000e+02
# 1345   CHEMBL1351178     P07550             EC50        =  9.990000e+02
# 1928   CHEMBL3645081     Q05397             IC50        =  9.990000e+02
# 1782   CHEMBL3642417     Q05397             IC50        =  9.990000e+02
# 11036   CHEMBL459647     P35968               Ki        =  9.990000e+02
# 1910   CHEMBL3645063     Q05397             IC50        =  9.990000e+02
# 1909   CHEMBL3645062     Q05397             IC50        =  9.990000e+02
# 1907   CHEMBL3645060     Q05397             IC50        =  9.990000e+02
# 1899   CHEMBL3645052     Q05397             IC50        =  9.990000e+02
# 1893   CHEMBL3645046     Q05397             IC50        =  9.990000e+02
# 1740     CHEMBL16984     P30543               Ki        =  9.990000e+02
# 1892   CHEMBL3645045     Q05397             IC50        =  9.990000e+02
# 1861   CHEMBL3645014     Q05397             IC50        =  9.990000e+02
# 1852   CHEMBL3645005     Q05397             IC50        =  9.990000e+02
# 904    CHEMBL1829741     P28845             IC50        =  9.990000e+02
# 1847   CHEMBL3645000     Q05397             IC50        =  9.990000e+02
# 957    CHEMBL2062812     Q05397             IC50        =  9.990000e+02
# 1783   CHEMBL3642418     Q05397             IC50        =  9.990000e+02
# 1874   CHEMBL3645027     Q05397             IC50        =  9.990000e+02
# 1777   CHEMBL3642412     Q05397             IC50        =  9.990000e+02
#
#              units                                             smiles dude_id  \
# 5501       ug.mL-1  n1c(c2c(nc1N)ncc(n2)CN(c1ccc(C(=O)N[C@H](C(=O)...     dyr
# 771             nM  C(=O)(N1[C@H](C(=O)N[C@H](C(=O)N([C@H](C(=O)N[...    reni
# 6546            nM  c12nc(nc(c1c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)CCC(...     dyr
# 5366            nM  n1c(c2c(nc1N)ncc(n2)CN(c1ccc(C(=O)N[C@H](C(=O)...     dyr
# 3274       ug.mL-1  n1c2c(c(nc1N)O)c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)...     dyr
# 1151       ug.mL-1  n1c2c(c(nc1N)O)c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)...    tysy
# 682    Unspecified    C(=O)(c1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb1
# 2423   Unspecified    C(=O)(c1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb2
# 6304   Unspecified   C(=O)(Nc1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb2
# 2437   Unspecified   C(=O)(Nc1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb1
# 243             nM  c12n([C@@H]3O[C@@H]([C@H](C3)O)CO)cnc1[C@@H](C...     ada
# 6033            nM  c1(ccc(cc1)OCc1ccccn1)C[C@H](NC(=O)O[C@@H]1[C@...   hivpr
# 650        ug.mL-1  [C@H]1(OC(=C[C@@H]([C@H]1NC(=O)C)N)C(=O)O)C(=O...    nram
# 713    Unspecified                      c1c(c(ccc1C(CNC(CCCCN)C)O)O)O   adrb1
# 2580   Unspecified                      c1c(c(ccc1C(CNC(CCCCN)C)O)O)O   adrb2
# 1096       ug.mL-1  [C@H]1(OC(=C[C@@H]([C@H]1NC(=O)C)N)C(=O)O)C(=O...    nram
# 6686            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 4052            nM  n1c(c2c(nc1N)ccc(c2)CNc1ccc(C(=O)NC(C(=O)O)CCC...     dyr
# 2291            nM  C1[C@H](OC(=O)N[C@H]([C@H](O)CN(CC(C)C)S(=O)(=...   hivpr
# 0               nM  c12nc(nc(c1CC(CN2)CCCc1ccc(C(=O)N[C@@H](C(=O)O...    pur2
# 552             nM                O=C([C@@H](CS)C)N1[C@H](C(=O)O)CCC1     ace
# 10062           nM  n1c2c(c(c3c1CCCC3)NCCn1nncc1CCCCCCN1[C@H](c3cc...    aces
# 10061           nM  n1c2c(c(c3c1CCCC3)NCCn1nncc1CCCCCCN1[C@@H](c3c...    aces
# 634        ug.mL-1  [C@H]1(OC(=C[C@@H]([C@H]1NC(=O)C)N)C(=O)O)C(=O...    nram
# 5528            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 1051            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCc1nc(oc1C)c1cc...   ppara
# 76              nM  c12c(nc(nc1O)N)NCC(N2)CCCc1ccc(C(=O)NC(C(=O)O)...    pur2
# 5480            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 5815            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 1049            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCc1nc(oc1C)c1c(...   ppara
# ...            ...                                                ...     ...
# 9206            nM  c1ccc(cc1)[C@@H](C)NC(=O)c1cc(C(=O)N[C@H]([C@H...   bace1
# 7367            nM      C1CCCC1CCNC(=O)c1cc(c(cc1)C)C(=O)Nc1ccc(N)nc1    mk14
# 4504            nM             COc1cccc(CNc2cccn3nc(Nc4ccncc4)nc23)c1    jak2
# 1613            nM   CN(C)CCCOc1ccc(cc1)c1cnc2c(cnn2c1)c1ccnc2ccccc12   tgfr1
# 402             nM                  Oc1nc(nc2c1cccc2)/C=C/c1ccc(cc1)C   casp3
# 956             nM  N(c1nn2c(c(ccc2)c2ccc(cc2)C(F)(F)F)n1)c1cc(ccc...    fak1
# 1764            nM  CN(Cc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCN(C)CC3...    fak1
# 1663            nM  CN(c1ccc(cc1)c1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)...    fak1
# 1709            nM  CS(=O)(=O)c1ccc(cc1)c1cccc2nc(Nc3cccc(CN4CCS(=...    fak1
# 1740            nM  CS(=O)(=O)c1ccc(cc1)c1cccn2nc(Nc3cccc(c3)N3CCN...    fak1
# 1757            nM  CN(Cc1ccccc1Nc1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)...    fak1
# 1345            nM  Clc1c(S(=O)(=O)N2CC(CCC2)C(=O)NCCCn2cncc2)cc(C...   adrb2
# 1928            nM  CS(=O)(=O)c1ccc(c(OCC(F)F)c1)c1cccn2nc(Nc3ccc4...    fak1
# 1782            nM  CN(c1ccccc1/C=C/c1cccn2nc(Nc3ccc(cc3)N3CCN(C)C...    fak1
# 11036           nM  c1c(cc2c(c1)c(ccn2)Oc1ccc(cc1F)NC(=O)c1c(n(n(c...   vgfr2
# 1910            nM  COc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N...    fak1
# 1909            nM     COc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCNCC3)nc12    fak1
# 1907            nM          COc1cccc(c1)c1cccn2nc(Nc3ccc4CNCc4c3)nc12    fak1
# 1899            nM  COc1ccc(cc1c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N(...    fak1
# 1893            nM  CN(C)C(=O)CN1CCc2ccc(Nc3nc4c(cccn4n3)c3cc(ccc3...    fak1
# 1740            nM  c12c(c(=O)n(c(=O)n1CCC)CCC)nc([nH]2)c1ccc(OCC(...   aa2ar
# 1892            nM  FC(F)COc1ccc(cc1c1cccn2nc(Nc3ccc4CCNCCc4c3)nc1...    fak1
# 1861            nM  Fc1ccc(cc1)n1cc(cn1)c1cccn2nc(Nc3ccc(cc3)C3CCN...    fak1
# 1852            nM  COc1ncccc1c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N(C...    fak1
# 904             nM            c1cccc(c1)[C@H]1CCN(C(=O)O1)c1cccc(c1)C    dhi1
# 1847            nM  CS(=O)(=O)CCN1CCc2ccc(Nc3nc4c(cccn4n3)c3cc(ccc...    fak1
# 957             nM  N(c1nn2c(c(ccc2)c2ccc(cc2)F)n1)c1cc(ccc1)N1CCN...    fak1
# 1783            nM  CC(Nc1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)nc12)c1cc...    fak1
# 1874            nM      CC(C)Oc1ccccc1c1cccn2nc(Nc3ccc4CCNCCc4c3)nc12    fak1
# 1777            nM  CS(=O)(=O)c1ccc(cc1)c1cccn2nc(Nc3cccc(c3)[C@@H...    fak1
#
#           pvalue
# 5501   20.481486
# 771    18.585027
# 6546   17.281498
# 5366   17.250264
# 3274   17.000000
# 1151   15.920819
# 682    15.494850
# 2423   15.494850
# 6304   15.327902
# 2437   15.327902
# 243    14.823909
# 6033   14.221849
# 650    14.000000
# 713    14.000000
# 2580   14.000000
# 1096   14.000000
# 6686   13.853872
# 4052   13.853872
# 2291   13.823909
# 0      13.721246
# 552    13.568636
# 10062  13.481486
# 10061  13.443697
# 634    13.397940
# 5528   13.318759
# 1051   13.301030
# 76     13.301030
# 5480   13.267606
# 5815   13.236572
# 1049   13.221849
# ...          ...
# 9206    6.000869
# 7367    6.000869
# 4504    6.000469
# 1613    6.000439
# 402     6.000435
# 956     6.000435
# 1764    6.000435
# 1663    6.000435
# 1709    6.000435
# 1740    6.000435
# 1757    6.000435
# 1345    6.000435
# 1928    6.000435
# 1782    6.000435
# 11036   6.000435
# 1910    6.000435
# 1909    6.000435
# 1907    6.000435
# 1899    6.000435
# 1893    6.000435
# 1740    6.000435
# 1892    6.000435
# 1861    6.000435
# 1852    6.000435
# 904     6.000435
# 1847    6.000435
# 957     6.000435
# 1783    6.000435
# 1874    6.000435
# 1777    6.000435
#
# [180295 rows x 9 columns]

# %%
data_actives = data.query('bioactivity_type in ["Ki", "Kd", "EC50", "IC50"] and pvalue > 6')

# %%
data_actives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180295 entries, 24 to 4407
# Data columns (total 9 columns):
# chembl_id           180295 non-null category
# uniprot_id          180295 non-null category
# bioactivity_type    180295 non-null category
# operator            180295 non-null category
# value               180295 non-null float64
# units               180295 non-null category
# smiles              178149 non-null category
# dude_id             180295 non-null category
# pvalue              180295 non-null float64
# dtypes: category(7), float64(2)
# memory usage: 31.8 MB

# %%
data_actives = data_actives.groupby(['chembl_id', 'dude_id'])['value'].count().sort_values()
# Out:
# chembl_id      dude_id
# CHEMBL320162   thrb         1
# CHEMBL3642309  jak2         1
# CHEMBL3642308  jak2         1
# CHEMBL3642306  jak2         1
#                fak1         1
# CHEMBL3642305  jak2         1
#                fak1         1
# CHEMBL3642304  jak2         1
#                fak1         1
# CHEMBL3642303  jak2         1
#                fak1         1
# CHEMBL3642302  jak2         1
#                fak1         1
# CHEMBL3642300  jak2         1
#                fak1         1
# CHEMBL364230   nos1         1
# CHEMBL3642297  jak2         1
# CHEMBL3642296  jak2         1
# CHEMBL3642295  jak2         1
#                fak1         1
# CHEMBL3642294  jak2         1
# CHEMBL3642293  jak2         1
# CHEMBL3642292  jak2         1
# CHEMBL3642291  jak2         1
# CHEMBL3642310  jak2         1
# CHEMBL3642290  jak2         1
# CHEMBL3642312  fak1         1
# CHEMBL3642313  jak2         1
# CHEMBL3642338  jak2         1
# CHEMBL3642336  jak2         1
#                          ...
# CHEMBL659      aces        64
# CHEMBL21       cah2        64
# CHEMBL409      andr        65
# CHEMBL94       aces        72
# CHEMBL220492   cah2        74
# CHEMBL7492     dyr         75
# CHEMBL972      aofb        78
# CHEMBL6        pgh2        78
# CHEMBL122      pgh2        78
# CHEMBL464859   aa2ar       80
# CHEMBL553      egfr        82
# CHEMBL939      egfr        87
# CHEMBL119      dyr         89
# CHEMBL17       cah2        90
# CHEMBL98       hdac8       91
#                hdac2       91
# CHEMBL218490   cah2        92
# CHEMBL131      gcr         93
# CHEMBL384467   gcr         96
# CHEMBL135      esr2       100
# CHEMBL19       cah2       101
# CHEMBL18       cah2       105
# CHEMBL6        pgh1       113
# CHEMBL135      esr1       116
# CHEMBL502      aces       142
# CHEMBL121      pparg      156
# CHEMBL118      pgh2       180
# CHEMBL34259    dyr        194
# CHEMBL95       aces       282
# CHEMBL20       cah2       336
# Name: value, Length: 126980, dtype: int64

# %%
(data
 .query('bioactivity_type in ["Ki", "Kd", "EC50", "IC50"] and pvalue > 6')
 .drop_duplicates(['chembl_id', 'dude_id'])
 .sort_values('value')
)
# Out:
#            chembl_id uniprot_id bioactivity_type operator         value  \
# 6546    CHEMBL428862     P00375               Ki        =  5.230000e-09
# 3274    CHEMBL267104     P00381             IC50        =  1.000000e-08
# 1151    CHEMBL267104     P00469             IC50        =  1.200000e-07
# 2423    CHEMBL157187     P18762               Kd        =  3.200000e-07
# 682     CHEMBL157187     P34971               Kd        =  3.200000e-07
# 6304    CHEMBL423055     P18762               Kd        =  4.700000e-07
# 2437    CHEMBL423055     P34971               Kd        =  4.700000e-07
# 243    CHEMBL2368596     P56658               Ki        =  1.500000e-06
# 6033    CHEMBL379921     Q72874               Ki        =  6.000000e-06
# 2580    CHEMBL160277     P18762               Kd        =  1.000000e-05
# 713     CHEMBL160277     P34971               Kd        =  1.000000e-05
# 6686    CHEMBL433973     Q72874               Ki        =  1.400000e-05
# 2291    CHEMBL206031     Q72874               Ki        =  1.500000e-05
# 0       CHEMBL117353     Q64737               Ki        =  1.900000e-05
# 10062  CHEMBL3314093     P22303               Kd        =  3.300000e-05
# 10061  CHEMBL3314092     P22303               Kd        =  3.600000e-05
# 5528    CHEMBL355306     Q72874               Ki        =  4.800000e-05
# 1051   CHEMBL1813006     Q07869             EC50        =  5.000000e-05
# 5480    CHEMBL353288     Q72874               Ki        =  5.400000e-05
# 5815    CHEMBL367454     Q72874               Ki        =  5.800000e-05
# 1049   CHEMBL1813005     Q07869             EC50        =  6.000000e-05
# 1837    CHEMBL177470     Q72874               Ki        =  6.100000e-05
# 1059   CHEMBL1813010     Q07869             EC50        =  7.000000e-05
# 4051    CHEMBL297088     P00374               Ki        =  9.000000e-05
# 2361   CHEMBL1813010     P37231             EC50        =  1.000000e-04
# 1021    CHEMBL180669     P42574             IC50        =  1.000000e-04
# 89        CHEMBL1580     P00813               Ki        =  1.000000e-04
# 285     CHEMBL284483     P00813               Ki        =  1.000000e-04
# 1169    CHEMBL149218     P00374               Ki        =  1.000000e-04
# 1115    CHEMBL146917     P00374               Ki        =  1.100000e-04
# ...              ...        ...              ...      ...           ...
# 4585    CHEMBL290024     P10608             IC50        =  9.980000e+02
# 1686    CHEMBL290024     P18090             IC50        =  9.980000e+02
# 7367    CHEMBL487431     Q16539             IC50        =  9.980000e+02
# 4504   CHEMBL3645106     O60674             IC50        =  9.989200e+02
# 1613   CHEMBL3668019     P36897             IC50        =  9.989900e+02
# 402    CHEMBL1421255     P42574             IC50        =  9.990000e+02
# 904    CHEMBL1829741     P28845             IC50        =  9.990000e+02
# 1663   CHEMBL3642295     Q05397             IC50        =  9.990000e+02
# 1740   CHEMBL3642375     Q05397             IC50        =  9.990000e+02
# 1709   CHEMBL3642344     Q05397             IC50        =  9.990000e+02
# 1757   CHEMBL3642392     Q05397             IC50        =  9.990000e+02
# 1764   CHEMBL3642399     Q05397             IC50        =  9.990000e+02
# 1899   CHEMBL3645052     Q05397             IC50        =  9.990000e+02
# 1782   CHEMBL3642417     Q05397             IC50        =  9.990000e+02
# 1909   CHEMBL3645062     Q05397             IC50        =  9.990000e+02
# 1893   CHEMBL3645046     Q05397             IC50        =  9.990000e+02
# 1910   CHEMBL3645063     Q05397             IC50        =  9.990000e+02
# 1892   CHEMBL3645045     Q05397             IC50        =  9.990000e+02
# 1874   CHEMBL3645027     Q05397             IC50        =  9.990000e+02
# 1861   CHEMBL3645014     Q05397             IC50        =  9.990000e+02
# 1777   CHEMBL3642412     Q05397             IC50        =  9.990000e+02
# 1852   CHEMBL3645005     Q05397             IC50        =  9.990000e+02
# 1847   CHEMBL3645000     Q05397             IC50        =  9.990000e+02
# 1345   CHEMBL1351178     P07550             EC50        =  9.990000e+02
# 1907   CHEMBL3645060     Q05397             IC50        =  9.990000e+02
# 956    CHEMBL2062811     Q05397             IC50        =  9.990000e+02
# 957    CHEMBL2062812     Q05397             IC50        =  9.990000e+02
# 1783   CHEMBL3642418     Q05397             IC50        =  9.990000e+02
# 1928   CHEMBL3645081     Q05397             IC50        =  9.990000e+02
# 1740     CHEMBL16984     P30543               Ki        =  9.990000e+02
#
#              units                                             smiles dude_id  \
# 6546            nM  c12nc(nc(c1c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)CCC(...     dyr
# 3274       ug.mL-1  n1c2c(c(nc1N)O)c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)...     dyr
# 1151       ug.mL-1  n1c2c(c(nc1N)O)c(c(cn2)CNc1ccc(C(=O)NC(C(=O)O)...    tysy
# 2423   Unspecified    C(=O)(c1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb2
# 682    Unspecified    C(=O)(c1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb1
# 6304   Unspecified   C(=O)(Nc1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb2
# 2437   Unspecified   C(=O)(Nc1ccc(cc1)C)NCCCCC(NCC(c1cc(c(cc1)O)O)O)C   adrb1
# 243             nM  c12n([C@@H]3O[C@@H]([C@H](C3)O)CO)cnc1[C@@H](C...     ada
# 6033            nM  c1(ccc(cc1)OCc1ccccn1)C[C@H](NC(=O)O[C@@H]1[C@...   hivpr
# 2580   Unspecified                      c1c(c(ccc1C(CNC(CCCCN)C)O)O)O   adrb2
# 713    Unspecified                      c1c(c(ccc1C(CNC(CCCCN)C)O)O)O   adrb1
# 6686            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 2291            nM  C1[C@H](OC(=O)N[C@H]([C@H](O)CN(CC(C)C)S(=O)(=...   hivpr
# 0               nM  c12nc(nc(c1CC(CN2)CCCc1ccc(C(=O)N[C@@H](C(=O)O...    pur2
# 10062           nM  n1c2c(c(c3c1CCCC3)NCCn1nncc1CCCCCCN1[C@H](c3cc...    aces
# 10061           nM  n1c2c(c(c3c1CCCC3)NCCn1nncc1CCCCCCN1[C@@H](c3c...    aces
# 5528            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 1051            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCc1nc(oc1C)c1cc...   ppara
# 5480            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 5815            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 1049            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCc1nc(oc1C)c1c(...   ppara
# 1837            nM  S(=O)(=O)(N(C[C@H]([C@@H](NC(=O)O[C@@H]1[C@H]2...   hivpr
# 1059            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCCc1nc(oc1C)c1c...   ppara
# 4051            nM  n1c(c2c(nc1N)ccc(c2)CNc1ccc(C(=O)NC(C(=O)O)CCC...     dyr
# 2361            nM  c1c(ccc(c1)C[C@@H](C(=O)O)OCC)OCCc1nc(oc1C)c1c...   pparg
# 1021            nM  n1(c(=O)c(nc(c1)C(C)(C)C)NCc1nonc1C)C(C(=O)N[C...   casp3
# 89              nM  n1cn(c2c1[C@@H](CNC=N2)O)[C@H]1C[C@H](O)[C@@H]...     ada
# 285             nM  n1cn(c2N=CNC[C@@H](O)c12)[C@H]1[C@H](O)[C@H](O...     ada
# 1169            nM  n1c(c2c(nc1N)ccc(c2C)CNc1ccc(C(=O)NC(C(=O)O)CC...     dyr
# 1115            nM  n1c(c2c(nc1N)ccc(c2Cl)CNc1ccc(C(=O)NC(C(=O)O)C...     dyr
# ...            ...                                                ...     ...
# 4585            nM        C(=NOCC(CNc1c(c2ccccc2)cccc1)O)(C1CC1)C1CC1   adrb2
# 1686            nM        C(=NOCC(CNc1c(c2ccccc2)cccc1)O)(C1CC1)C1CC1   adrb1
# 7367            nM      C1CCCC1CCNC(=O)c1cc(c(cc1)C)C(=O)Nc1ccc(N)nc1    mk14
# 4504            nM             COc1cccc(CNc2cccn3nc(Nc4ccncc4)nc23)c1    jak2
# 1613            nM   CN(C)CCCOc1ccc(cc1)c1cnc2c(cnn2c1)c1ccnc2ccccc12   tgfr1
# 402             nM                  Oc1nc(nc2c1cccc2)/C=C/c1ccc(cc1)C   casp3
# 904             nM            c1cccc(c1)[C@H]1CCN(C(=O)O1)c1cccc(c1)C    dhi1
# 1663            nM  CN(c1ccc(cc1)c1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)...    fak1
# 1740            nM  CS(=O)(=O)c1ccc(cc1)c1cccn2nc(Nc3cccc(c3)N3CCN...    fak1
# 1709            nM  CS(=O)(=O)c1ccc(cc1)c1cccc2nc(Nc3cccc(CN4CCS(=...    fak1
# 1757            nM  CN(Cc1ccccc1Nc1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)...    fak1
# 1764            nM  CN(Cc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCN(C)CC3...    fak1
# 1899            nM  COc1ccc(cc1c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N(...    fak1
# 1782            nM  CN(c1ccccc1/C=C/c1cccn2nc(Nc3ccc(cc3)N3CCN(C)C...    fak1
# 1909            nM     COc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCNCC3)nc12    fak1
# 1893            nM  CN(C)C(=O)CN1CCc2ccc(Nc3nc4c(cccn4n3)c3cc(ccc3...    fak1
# 1910            nM  COc1cccc(c1)c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N...    fak1
# 1892            nM  FC(F)COc1ccc(cc1c1cccn2nc(Nc3ccc4CCNCCc4c3)nc1...    fak1
# 1874            nM      CC(C)Oc1ccccc1c1cccn2nc(Nc3ccc4CCNCCc4c3)nc12    fak1
# 1861            nM  Fc1ccc(cc1)n1cc(cn1)c1cccn2nc(Nc3ccc(cc3)C3CCN...    fak1
# 1777            nM  CS(=O)(=O)c1ccc(cc1)c1cccn2nc(Nc3cccc(c3)[C@@H...    fak1
# 1852            nM  COc1ncccc1c1cccn2nc(Nc3ccc(cc3)C3CCN(CC(=O)N(C...    fak1
# 1847            nM  CS(=O)(=O)CCN1CCc2ccc(Nc3nc4c(cccn4n3)c3cc(ccc...    fak1
# 1345            nM  Clc1c(S(=O)(=O)N2CC(CCC2)C(=O)NCCCn2cncc2)cc(C...   adrb2
# 1907            nM          COc1cccc(c1)c1cccn2nc(Nc3ccc4CNCc4c3)nc12    fak1
# 956             nM  N(c1nn2c(c(ccc2)c2ccc(cc2)C(F)(F)F)n1)c1cc(ccc...    fak1
# 957             nM  N(c1nn2c(c(ccc2)c2ccc(cc2)F)n1)c1cc(ccc1)N1CCN...    fak1
# 1783            nM  CC(Nc1cccn2nc(Nc3ccc(cc3)N3CCN(C)CC3)nc12)c1cc...    fak1
# 1928            nM  CS(=O)(=O)c1ccc(c(OCC(F)F)c1)c1cccn2nc(Nc3ccc4...    fak1
# 1740            nM  c12c(c(=O)n(c(=O)n1CCC)CCC)nc([nH]2)c1ccc(OCC(...   aa2ar
#
#           pvalue
# 6546   17.281498
# 3274   17.000000
# 1151   15.920819
# 2423   15.494850
# 682    15.494850
# 6304   15.327902
# 2437   15.327902
# 243    14.823909
# 6033   14.221849
# 2580   14.000000
# 713    14.000000
# 6686   13.853872
# 2291   13.823909
# 0      13.721246
# 10062  13.481486
# 10061  13.443697
# 5528   13.318759
# 1051   13.301030
# 5480   13.267606
# 5815   13.236572
# 1049   13.221849
# 1837   13.214670
# 1059   13.154902
# 4051   13.045757
# 2361   13.000000
# 1021   13.000000
# 89     13.000000
# 285    13.000000
# 1169   13.000000
# 1115   12.958607
# ...          ...
# 4585    6.000869
# 1686    6.000869
# 7367    6.000869
# 4504    6.000469
# 1613    6.000439
# 402     6.000435
# 904     6.000435
# 1663    6.000435
# 1740    6.000435
# 1709    6.000435
# 1757    6.000435
# 1764    6.000435
# 1899    6.000435
# 1782    6.000435
# 1909    6.000435
# 1893    6.000435
# 1910    6.000435
# 1892    6.000435
# 1874    6.000435
# 1861    6.000435
# 1777    6.000435
# 1852    6.000435
# 1847    6.000435
# 1345    6.000435
# 1907    6.000435
# 956     6.000435
# 957     6.000435
# 1783    6.000435
# 1928    6.000435
# 1740    6.000435
#
# [126980 rows x 9 columns]
