# %%
import pandas as pd

# %%
from joblib import Parallel, delayed

# %%
# conda install -c chembl chembl_webresource_client
import chembl_webresource_client as chembl

# %%
from ChEMBL import get_chembl_id, chembl_to_data_frame

# %%
def get_dude_dataframe(dude_id):
    """Download list of active compounds for a DUDe id and return a DataFrame"""
    
    # get Uniprot IDs associatet with DUDe
    # TODO: do we want to extend that?
    uniprot_ids = pd.read_csv('http://dude.docking.org/targets/%s/uniprot.txt' % dude_id, 
                              header=None, names=['uniprot_id']).uniprot_id.tolist()

    # get activities from ChEMBL
    data = pd.concat(chembl_to_data_frame(uniprot_id) for uniprot_id in uniprot_ids)
    
    # Resolve SMILES for ChEMBL IDs locally (very slow with web services for large targets)
    chembl_smiles = pd.read_csv('chembl_23.smi.gz', sep='\t', header=None,names=['smiles', 'chembl_id'])
    data_full = data.set_index('chembl_id').join(chembl_smiles.set_index('chembl_id')).reset_index()
    
    data_full['dude_id'] = dude_id
    
    # for memory efficiency set appropriate dtypes
    cat_columns = ['dude_id', 
                   'chembl_id', 
                   'uniprot_id',
                   'units', 
                   'operator', 
                   'bioactivity_type',
                   'smiles'
                  ]
    for col in cat_columns:
        data_full[col] = data_full[col].astype('category')
    
    data_full.to_csv('data_dude_%s.csv' % dude_id)
    # return data_full

# %%
# %%time
data = get_dude_dataframe('aa2ar')
# Out:
# CPU times: user 7.55 s, sys: 152 ms, total: 7.7 s
# Wall time: 8.57 s

# %%
dude_ids = ['lck', 'src', 'ada17', 'hivpr', 'mk14', 'mmp13', 'aa2ar', 'bace1', 'pparg', 'parp1', 'ace', 'thrb', 'cdk2', 'esr1', 'esr2', 'vgfr2', 'fnta', 'drd3', 'csf1r', 'dhi1', 'casp3', 'gria2', 'kit', 'dyr', 'braf', 'tryb1', 'hdac8', 'aldr', 'akt1', 'ital', 'kpcb', 'tysy', 'ppard', 'hivint', 'ppara', 'urok', 'wee1', 'reni', 'grik1', 'aces', 'fa10', 'dpp4', 'adrb2', 'jak2', 'hivrt', 'fkb1a', 'cah2', 'kif11', 'try1', 'adrb1', 'akt2', 'rock1', 'pa2ga', 'pygm', 'mapk2', 'fa7', 'tgfr1', 'mk10', 'fak1', 'gcr', 'hdac2', 'prgr', 'ptn1', 'nram', 'abl1', 'hs90a', 'egfr', 'hxk4', 'mk01', 'cxcr4', 'lkha4', 'ada', 'pur2', 'pnph', 'andr', 'rxra', 'fpps', 'cp3a4', 'met', 'ampc', 'mp2k1', 'pyrd', 'pgh1', 'kith', 'thb', 'comt', 'cp2c9', 'aofb', 'fabp4', 'mcr', 'inha', 'pgh2', 'def', 'xiap', 'glcm', 'pde5a', 'nos1', 'sahh', 'hmdh', 'igf1r', 'plk1', 'fgfr1']

# %%
# %%time
# We need to run this few times, as some errors araise, I guess we are hitting some limits on ChEMBL there...
out = Parallel(n_jobs=1, verbose=1)(delayed(get_dude_dataframe)(dude_id) for dude_id in dude_ids)
# data = pd.concat(out)

# %%
len(data)
# Out:
# 11989

# %%
data.dtypes
# Out:
# chembl_id           category
# uniprot_id          category
# bioactivity_type    category
# operator            category
# value                float64
# units               category
# smiles              category
# dude_id             category
# dtype: object

# %%
data.sort_values('value')
# Out:
#            chembl_id uniprot_id bioactivity_type operator        value units  \
# 9639    CHEMBL460532     P29274         Activity        =       -74.00     %
# 11090   CHEMBL601874     P29274       Inhibition        =       -33.00     %
# 9914    CHEMBL475345     P29274         Activity        =       -20.00     %
# 9881    CHEMBL472925     P29274         Activity        =       -19.00     %
# 11256   CHEMBL605123     P29274       Inhibition        =       -19.00     %
# 7108   CHEMBL3401302     P29274       Inhibition        =       -18.00     %
# 10407   CHEMBL522001     P29274         Activity        =       -17.30     %
# 4794   CHEMBL2391147     P29274       Inhibition        =       -16.00     %
# 208    CHEMBL1082390     P29274       Inhibition        =       -16.00     %
# 6928   CHEMBL3334797     P29274       Inhibition        =       -14.70     %
# 10166   CHEMBL493748     P29274         Activity        =       -11.90     %
# 9887    CHEMBL473628     P29274         Activity        =       -11.40     %
# 9915    CHEMBL475346     P29274         Activity        =       -11.20     %
# 252    CHEMBL1087078     P30543               Ki        =       -10.00    nM
# 11049   CHEMBL600861     P29274       Inhibition        =       -10.00     %
# 422    CHEMBL1095696     P30543               Ki        =        -8.00    nM
# 5149    CHEMBL256185     P29274       Inhibition        =        -8.00     %
# 10836   CHEMBL592537     P29274       Inhibition        =        -8.00     %
# 8734    CHEMBL389912     P29274       Inhibition        =        -8.00     %
# 8273   CHEMBL3774784     P29274         Activity        =        -7.30     %
# 7678   CHEMBL3613642     P29274       Inhibition        =        -7.00     %
# 5539    CHEMBL272155     P29274       Inhibition        =        -7.00     %
# 10246   CHEMBL510282     P29274       Inhibition        =        -6.00     %
# 11053   CHEMBL601021     P29274       Inhibition        =        -6.00     %
# 4158   CHEMBL2206397     P29274       Inhibition        =        -6.00     %
# 4153   CHEMBL2203713     P29274       Inhibition        =        -6.00     %
# 4708   CHEMBL2381116     P29274       Inhibition        =        -5.80     %
# 6150   CHEMBL3100160     P29274       Inhibition        =        -5.00     %
# 7709   CHEMBL3622346     P29274       Inhibition        =        -5.00     %
# 209    CHEMBL1082390     P29274       Inhibition        =        -5.00     %
# ...              ...        ...              ...      ...          ...   ...
# 5949   CHEMBL3088346     P29274               Ki        >    100000.00    nM
# 1211      CHEMBL1424     P29274             EC50        >    100000.00    nM
# 5935   CHEMBL3088333     P29274               Ki        >    100000.00    nM
# 3448   CHEMBL2112095     P29274               Ki        =    100000.00    nM
# 4740   CHEMBL2381772     P29274             IC50        >    100000.00    nM
# 11797    CHEMBL87496     P29274               Ki        =    106000.00    nM
# 3502   CHEMBL2112673     P30543               Ki        =    106000.00    nM
# 6541    CHEMBL324036     P30543               Ki        =    113000.00    nM
# 5707    CHEMBL279898     P30543               Kb        =    120000.00    nM
# 11078   CHEMBL601628     P29274               Ki        =    120000.00    nM
# 11623      CHEMBL699     P46616               Ki        =    135000.00    nM
# 3221     CHEMBL20613     P46616               Ki        >    150000.00    nM
# 11355   CHEMBL607911     P30543               Ki        =    189000.00    nM
# 8021   CHEMBL3742187     P29274               Ki        >    200000.00    nM
# 8018   CHEMBL3741961     P29274               Ki        >    200000.00    nM
# 7960   CHEMBL3739476     P29274               Ki        >    200000.00    nM
# 7968   CHEMBL3740044     P29274               Ki        >    200000.00    nM
# 7971   CHEMBL3740152     P29274               Ki        >    200000.00    nM
# 7985   CHEMBL3740794     P29274               Ki        >    200000.00    nM
# 7994   CHEMBL3741118     P29274               Ki        >    200000.00    nM
# 7974   CHEMBL3740229     P29274               Ki        >    200000.00    nM
# 7976   CHEMBL3740409     P29274               Ki        >    200000.00    nM
# 8012   CHEMBL3741891     P29274               Ki        >    200000.00    nM
# 3779   CHEMBL2113696     P30543               Ki        =    220000.00    nM
# 2398       CHEMBL193     P29274               Ki        =    244000.00    nM
# 17      CHEMBL100389     P29274               Ki        =    250000.00    nM
# 28      CHEMBL100909     P29274               Ki        =    292000.00    nM
# 6299    CHEMBL314792     P30543               Ki        =    346000.00    nM
# 6333    CHEMBL317052     P29274               Ki        =   1269000.00    nM
# 8797     CHEMBL39388     P29274             EC50        =  15848931.92    nM
#
#                                                   smiles dude_id
# 9639   c1ccc2c(c1)c(cc(n2)Nc1ccc(c(c1)Cl)Cl)NC(=O)C1C...   aa2ar
# 11090                     c1c(c(cc2c1oc(c(c2=O)C=O)N)C)C   aa2ar
# 9914   c1ccc2c(c1)c(cc(n2)Nc1ccc(c(c1)Cl)Cl)NC(=O)c1c...   aa2ar
# 9881   c1ccc2c(c1)c(cc(n2)Nc1ccc(c(c1)Cl)Cl)NC(=O)C1C...   aa2ar
# 11256  c1cc(c2c(c1OC)oc(c2)C(=O)Nc1ccc(cc1)OC)c1nc(sc...   aa2ar
# 7108                 c1(ccc(cc1)NC(=O)CCCN)C(=O)Nc1sccn1   aa2ar
# 10407  C12CC3(C(CC(C3)C2)C1)c1[nH]c2c(c(nc3c2cccc3)Nc...   aa2ar
# 4794            [C@H]1(N(C(=O)C[C@@H]1c1ccccc1)CC(=O)N)C   aa2ar
# 208          c1(ccc2c(c1OC)oc(c2)C(=O)Nc1ccncc1)N1CCOCC1   aa2ar
# 6928                N1(C(c2cc(c(cc2)Cl)Cl)CCN(C)C)CCOCC1   aa2ar
# 10166  n1c(c2c([nH]c(n2)C2CCOCC2)c2c1cccc2)Nc1ccc(c(c...   aa2ar
# 9887   n1c(c2c([nH]c(n2)C2CCCCC2)c2c1cccc2)Nc1cc(cc(c...   aa2ar
# 9915   c1ccc2c(c1)c1c(c(n2)Nc2ccc(c(c2)Cl)Cl)[nH]c(n1...   aa2ar
# 252              c1(nc2c(c(n1)OCC#C)c1c(s2)CCC1)c1ccccc1   aa2ar
# 11049  c1(c2c(cc3c1c(c(o3)N)C(=O)OC)c(c(o2)N)C(=O)OC)...   aa2ar
# 422    c1(nc2c(c(=O)n1Cc1nnn(c1)CCC(C(C(C(C(C(C(C(F)(...   aa2ar
# 5149   n1c(nc(c2c1n(cn2)[C@@H]1S[C@@H]([C@H]([C@H]1O)...   aa2ar
# 10836  c1cc(c2c(c1OC)oc(c2)C(=O)Nc1ccccc1)c1ccc(cc1)C...   aa2ar
# 8734   n1(cnc2c1nc(nc2NCc1cccc2c1cccc2)Cl)[C@H]1[C@@H...   aa2ar
# 8273   C(=O)([C@@H](C)c1cc(c(cc1)c1cc(ccc1)OC(=O)NCCC...   aa2ar
# 7678   c1c(cc(c(c1)C(=O)Nc1ccc(cc1)S(=O)(=O)N1CCN(CC1...   aa2ar
# 5539   n1c(nc(c2c1n(cn2)[C@@H]1S[C@@H]([C@H]([C@H]1O)...   aa2ar
# 10246                   c1nc(c2c(n1)[nH]c(n2)SCCC(=O)O)N   aa2ar
# 11053                 c1(nc(c2c(n1)[nH]cn2)SCCCCC(=O)O)N   aa2ar
# 4158                         c1(cccc(c1Cc1[nH]ccn1)CC)CC   aa2ar
# 4153              c1(ccc2c(c1)CCN2C1CCNCC1)NC(=N)c1cccs1   aa2ar
# 4708   c1c(c(ccn1)N1CCNCC1)NC(=O)c1csc(n1)N1C(=O)c2c(...   aa2ar
# 6150    n1c(cc(nc1n1nc(cc1C)C)Nc1ncccn1)N1Cc2c(CC1)cccc2   aa2ar
# 7709   O=S1(=O)N=C(NC[C@]2(CC[C@H](CC2)O)c2ccccc2)c2c...   aa2ar
# 209          c1(ccc2c(c1OC)oc(c2)C(=O)Nc1ccncc1)N1CCOCC1   aa2ar
# ...                                                  ...     ...
# 5949        n1cnc2c(c1N1CCC(CC1)N1CCCCC1)nc(s2)Nc1ccccc1   aa2ar
# 1211                      [nH]1c2[nH]c(=O)[nH]c(=O)c2nc1   aa2ar
# 5935           n1cnc2c(c1N1CCN(CC1)C)nc(s2)Nc1ccc(cc1)Cl   aa2ar
# 3448   [C@@]12(n3c4c(nc3)c(ncn4)N)[C@@H](C2)[C@@H]([C...   aa2ar
# 4740   n1c(nc2n(c1NCCCC(=O)OCC)nc(n2)c1ccco1)NCCc1ccc...   aa2ar
# 11797              c12c(sc(c1CCCC2=O)C(=O)OCC)SCc1ccccc1   aa2ar
# 3502            c12c(sc(c1CC(CC2=O)(C)C)C(=O)OCC)SC(CC)C   aa2ar
# 6541     c12c(c(=O)n(c(=O)n1CCCC)CCCC)nc([nH]2)CCCC(=O)O   aa2ar
# 5707                    c1nc2c([nH]1)c(=O)[nH]c(=O)n2CCC   aa2ar
# 11078     c1ccc2c(c1)C(=O)c1c(C2=O)c(cc(c1N)C(=O)NCCCC)N   aa2ar
# 11623                   c12c(c(=O)n(c(=O)n1C)C)n(cn2)CCO   aa2ar
# 3221           n1(c2c(c(=O)n(c1=O)CCC(C)C)nc[nH]2)CC(C)C   aa2ar
# 11355  n1(c2c(c3=N[C@H](Cn3cn2)c2ccccc2)nc1)C1[C@H]([...   aa2ar
# 8021                C1CCN2[C@@H](C1)CN(C2=N)Cc1ccccc1.Cl   aa2ar
# 8018        [C@H]1(NC(=N)N(C1)Cc1ccccc1)Cc1ccc(cc1)OC.Cl   aa2ar
# 7960         c1ccc2c(c1)C[C@@H]1N(C2)C(=N)N(C1)CCCCCC.Cl   aa2ar
# 7968         [C@H]1(NC(=N)N(C1)Cc1ccccc1)Cc1ccc(cc1)F.Cl   aa2ar
# 7971         [C@H]1(NC(=N)N(C1)Cc1ccccc1)Cc1ccc(cc1)O.Cl   aa2ar
# 7985   c1ccc2c(c1)C[C@@H]1N(C2)C(=N)N(C1)CCN1CCOCC1.C...   aa2ar
# 7994   c1ccc2c(c1)C[C@@H]1N(C2)C(=N)N(C1)CCc1ncccc1.C...   aa2ar
# 7974                    [C@H]1(NC(=N)N(C1)Cc1ccccc1)C.Cl   aa2ar
# 7976             C1(N(C(=N)N(C1)Cc1ccccc1)C)Cc1ccccc1.Cl   aa2ar
# 8012            [C@H]1(NC(=N)N(C1)Cc1ccccc1)Cc1ccccc1.Cl   aa2ar
# 3779   n1(c2c(c(nc(n2)Cl)NCc2ccccc2)nc1)[C@@H]1O[C@H]...   aa2ar
# 2398   C1(=C(NC(=C(C1c1c(cccc1)[N+](=O)[O-])C(=O)OC)C...   aa2ar
# 17                 c12c(nn(n2)C2CCCCC2)c(=O)n(c(=O)n1C)C   aa2ar
# 28                  c12c(c(=O)n(c(=O)n1C)C)n(nn2)C1CCCC1   aa2ar
# 6299                      c12c(C3(C(=O)N1)CCCC3)c(ncn2)O   aa2ar
# 6333   n1(c2nc(nc(c2nc1)N)n1ncc(c1)C(=O)NC)[C@H]1[C@@...   aa2ar
# 8797                    c12c(sc(n1)N)Cc1c2cccc1OC(=O)C.I   aa2ar
#
# [11989 rows x 8 columns]

# %%
data.bioactivity_type.unique()
# Out:
# array(['IC50', 'Ki', 'Inhibition', 'Activity', 'Displacement', 'INH',
#        'EC50', 'Kd', 'Kb', 'I', 'pC2A', 'Efficacy', 'pKi',
#        'Inhibition (at concentration M)', 'Loss', 'pKi(uM)', 'ED50',
#        'Emax', 'Alloste ic enhan er (AE)', 'pKb', 'Ratio', 'Potency ratio',
#        'Relative potency', 'Kbapp', 'log(activity)', 'pKA', 'Ratio IC50',
#        'Bmax', 'Time', 'FC', 'AE activity', 'Solubility', 'KA', 'Kdiss',
#        'T1/2'], dtype=object)

# %%
data.units.unique()
# Out:
# array(['nM', '%', 'pmol/ml', 'uM', 'Unspecified', 'mM', 'pmol', 'pM mg-1',
#        'min', '/s', 'hr'], dtype=object)

# %%
data.value.describe()
# Out:
# count    1.198900e+04
# mean     5.276524e+03
# std      1.459500e+05
# min     -7.400000e+01
# 25%      1.400000e+01
# 50%      7.800000e+01
# 75%      1.050000e+03
# max      1.584893e+07
# Name: value, dtype: float64

# %%
targets = chembl.TargetResource()

# %%
targets.get(uniprot='P19785')
# Out:
# {'bioactivityCount': 2172,
#  'chemblId': 'CHEMBL2094113',
#  'compoundCount': 365,
#  'description': 'Estrogen receptor',
#  'geneNames': 'Unspecified',
#  'organism': 'Mus musculus',
#  'preferredName': 'Estrogen receptor',
#  'proteinAccession': 'P19785',
#  'synonyms': 'Esr ,Estra,Estrogen receptor,Nuclear receptor subfamily 3 group A member 1,Esr1,Estr,Nr3a1,ER,Estradiol receptor,ER-alpha',
#  'targetType': 'PROTEIN FAMILY'}
