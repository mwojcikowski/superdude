# %%
from os.path import isfile

# %%
import pandas as pd

# %%
from joblib import Parallel, delayed

# %%
# conda install -c chembl chembl_webresource_client
import chembl_webresource_client as chembl

# %%
from ChEMBL import get_chembl_id, chembl_to_data_frame

# %%
def get_dude_dataframe(dude_id):
    """Download list of active compounds for a DUDe id and return a DataFrame"""
    
    # blacklist Uniprot IDs - investigate those and move to dictionary
    blacklist = []
    
    if isfile('data/data_dude_%s.csv' % dude_id):
        return None
    
    # get Uniprot IDs associatet with DUDe
    # TODO: do we want to extend that?
    uniprot_map = {
        # Obsolete
        'P0A5Y6': 'P9WGR1',
        'P45351': 'P0CS13',
        # Not mapping
        'P68404': 'P05771',
    }
    
    uniprot_ids = pd.read_csv('http://dude.docking.org/targets/%s/uniprot.txt' % dude_id, 
                              header=None, names=['uniprot_id']).uniprot_id
    uniprot_ids = uniprot_ids.replace(uniprot_map).tolist()
   
    

    if len(uniprot_ids) == 0:
        return None
    
    # get activities from ChEMBL (try 5 times, again ChEMBL is fussy)
    for _ in range(5):
        try:
            data = pd.concat(chembl_to_data_frame(uniprot_id) 
                             for uniprot_id in uniprot_ids
                             if uniprot_id not in blacklist
                            )
            break
        except ValueError as e:
            pass
    else:
        return None
    
    # Resolve SMILES for ChEMBL IDs locally (very slow with web services for large targets)
    chembl_smiles = pd.read_csv('chembl_23.smi.gz', sep='\t', header=None,names=['smiles', 'chembl_id'])
    data_full = data.set_index('chembl_id').join(chembl_smiles.set_index('chembl_id')).reset_index()
    
    data_full['dude_id'] = dude_id
    
    # for memory efficiency set appropriate dtypes
    cat_columns = ['dude_id', 
                   'chembl_id', 
                   'uniprot_id',
                   'units', 
                   'operator', 
                   'bioactivity_type',
                   'smiles'
                  ]
    for col in cat_columns:
        data_full[col] = data_full[col].astype('category')
    
    data_full.to_csv('data/data_dude_%s.csv' % dude_id)
    # return data_full

# %%
# %%time
data = get_dude_dataframe('kpcb')
# Out:
# CPU times: user 32 µs, sys: 4 µs, total: 36 µs
# Wall time: 40.5 µs

# %%
dude_ids = ['lck', 'src', 'ada17', 'hivpr', 'mk14', 'mmp13', 'aa2ar', 'bace1', 'pparg', 'parp1', 'ace', 'thrb', 'cdk2', 'esr1', 'esr2', 'vgfr2', 'fnta', 'drd3', 'csf1r', 'dhi1', 'casp3', 'gria2', 'kit', 'dyr', 'braf', 'tryb1', 'hdac8', 'aldr', 'akt1', 'ital', 'kpcb', 'tysy', 'ppard', 'hivint', 'ppara', 'urok', 'wee1', 'reni', 'grik1', 'aces', 'fa10', 'dpp4', 'adrb2', 'jak2', 'hivrt', 'fkb1a', 'cah2', 'kif11', 'try1', 'adrb1', 'akt2', 'rock1', 'pa2ga', 'pygm', 'mapk2', 'fa7', 'tgfr1', 'mk10', 'fak1', 'gcr', 'hdac2', 'prgr', 'ptn1', 'nram', 'abl1', 'hs90a', 'egfr', 'hxk4', 'mk01', 'cxcr4', 'lkha4', 'ada', 'pur2', 'pnph', 'andr', 'rxra', 'fpps', 'cp3a4', 'met', 'ampc', 'mp2k1', 'pyrd', 'pgh1', 'kith', 'thb', 'comt', 'cp2c9', 'aofb', 'fabp4', 'mcr', 'inha', 'pgh2', 'def', 'xiap', 'glcm', 'pde5a', 'nos1', 'sahh', 'hmdh', 'igf1r', 'plk1', 'fgfr1']

# %%
# %%time
# We need to run this few times, as some errors araise, I guess we are hitting some limits on ChEMBL there...
out = Parallel(n_jobs=-1, verbose=1)(delayed(get_dude_dataframe)(dude_id) for dude_id in dude_ids)
# data = pd.concat(out)
# Out:
# CPU times: user 57.6 ms, sys: 41.3 ms, total: 98.9 ms
# Wall time: 197 ms
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed:    0.0s finished

# %% [markdown]
# # Read master DataFrame with all data

# %%
data = pd.concat(pd.read_csv('data/data_dude_%s.csv' % dude_id, index_col=0) for dude_id in dude_ids)
cat_columns = ['dude_id', 
               'chembl_id', 
               'uniprot_id',
               'units', 
               'operator', 
               'bioactivity_type',
               'smiles'
              ]
for col in cat_columns:
    data[col] = data[col].astype('category')
data['value'] = data['value'].astype(float)

# %%
len(data)
# Out:
# 487498

# %%
data.dtypes
# Out:
# chembl_id           category
# uniprot_id          category
# bioactivity_type    category
# operator            category
# value                float64
# units               category
# smiles              category
# dude_id             category
# dtype: object

# %%
data.sort_values('value')
# Out:
#            chembl_id uniprot_id bioactivity_type operator         value  \
# 600     CHEMBL321397     P06536      Weight gain        = -2.360000e+02
# 590     CHEMBL320320     P06536      Weight gain        = -2.240000e+02
# 64      CHEMBL113032     P06536      Weight gain        = -1.860000e+02
# 30      CHEMBL109690     P06536      Weight gain        = -1.800000e+02
# 69      CHEMBL113561     P06536      Weight gain        = -1.450000e+02
# 32      CHEMBL109690     P06536      Weight gain        = -1.400000e+02
# 587     CHEMBL320320     P06536      Weight gain        = -1.290000e+02
# 597     CHEMBL321397     P06536      Weight gain        = -1.270000e+02
# 6402    CHEMBL306894     P35354       Inhibition        = -1.250000e+02
# 11330    CHEMBL67324     P35354       Inhibition        = -1.250000e+02
# 1383       CHEMBL135     P06211           Weight        = -1.212000e+02
# 797        CHEMBL135     Q62986           Weight        = -1.212000e+02
# 8760       CHEMBL691     Q62986           Weight        = -1.202000e+02
# 1244      CHEMBL1405     Q62986           Weight        = -1.202000e+02
# 11847      CHEMBL691     P06211           Weight        = -1.202000e+02
# 1675      CHEMBL1405     P06211           Weight        = -1.202000e+02
# 11048   CHEMBL497906     P03372         Activity        = -1.110000e+02
# 6270   CHEMBL3746293     Q16539       Inhibition        = -1.097000e+02
# 6401    CHEMBL306894     P35354       Inhibition        = -1.000000e+02
# 7928     CHEMBL35063     P35355           Change        = -1.000000e+02
# 4176    CHEMBL388978     P24941       Inhibition        = -1.000000e+02
# 5740    CHEMBL284477     P35355           Change        = -1.000000e+02
# 8596     CHEMBL37599     P35355           Change        = -1.000000e+02
# 14677      CHEMBL554     P00533       Inhibition        = -9.900000e+01
# 4214   CHEMBL3815046     P06239         Activity        = -9.900000e+01
# 4448   CHEMBL2425144     Q16539       Inhibition        = -9.600000e+01
# 4212   CHEMBL3814140     P06239         Activity        = -9.500000e+01
# 2777   CHEMBL2425144     P06239       Inhibition        = -9.400000e+01
# 10025  CHEMBL3613695     P00533       Inhibition        = -9.000000e+01
# 1942       CHEMBL503     P04035       Inhibition        = -8.997000e+01
# ...              ...        ...              ...      ...           ...
# 6939     CHEMBL48180     Q72874               Ki        =  1.995262e+17
# 3626    CHEMBL299376     Q72874               Ki        =  1.995262e+17
# 7003     CHEMBL51463     Q72874               Ki        =  1.995262e+17
# 6970     CHEMBL49288     Q72874               Ki        =  2.041738e+17
# 3624    CHEMBL299375     Q72874               Ki        =  2.691535e+17
# 3666    CHEMBL300858     Q72874               Ki        =  2.951209e+17
# 2731    CHEMBL298006     P19643               Ki        =  3.311311e+17
# 7013     CHEMBL52051     Q72874               Ki        =  3.467369e+17
# 7004     CHEMBL51463     Q72874               Ki        =  3.715352e+17
# 6252    CHEMBL408723     Q72874               Ki        =  4.570882e+17
# 3600    CHEMBL298303     Q72874               Ki        =  4.786301e+17
# 3680    CHEMBL301365     Q72874               Ki        =  7.079458e+17
# 7014     CHEMBL52130     Q72874               Ki        =  1.000000e+18
# 4827    CHEMBL424940     P56560             IC50        =  1.000000e+18
# 609     CHEMBL120070     P00918             IC50        =  1.122018e+18
# 590     CHEMBL120018     P00918             IC50        =  1.230269e+18
# 4932     CHEMBL45069     P19643               Ki        =  1.318257e+18
# 655     CHEMBL121291     P00918             IC50        =  1.621810e+18
# 6907     CHEMBL46337     Q72874               Ki        =  1.659587e+18
# 3669    CHEMBL300968     Q72874               Ki        =  2.630268e+18
# 3513    CHEMBL295414     Q72874               Ki        =  2.951209e+18
# 3645    CHEMBL300050     Q72874               Ki        =  4.168694e+18
# 1809    CHEMBL174847     P00918               Ki        =  4.570882e+18
# 3636    CHEMBL299659     Q72874               Ki        =  4.570882e+18
# 6944     CHEMBL48565     Q72874               Ki        =  4.570882e+18
# 387        CHEMBL114     Q72874               Ki        =  8.317638e+18
# 7393    CHEMBL358263     P00918               Ki        =  1.862087e+19
# 1220    CHEMBL148660     P00918               Ki        =  3.981072e+19
# 1247    CHEMBL150043     P00918               Ki        =  2.089296e+20
# 8770    CHEMBL444536     P00918               Ki        =  1.202264e+21
#
#              units                                             smiles dude_id
# 600    Unspecified  C12(C(=O)N(C(=O)N(C1=O)C)C)O[C@@H]1C(=CC2)[C@@...     gcr
# 590    Unspecified  C12(C(=O)c3c(C1=O)cccc3)O[C@@H]1C(=CC2)[C@@]2(...     gcr
# 64     Unspecified  c12n(ncc1C[C@@]1(C3=CCCC([C@H]3CCC1=C2)(C(=O)O...     gcr
# 30     Unspecified  C12(C(=O)NC(=O)NC1=O)O[C@@H]1C(=CC2)[C@@]2(C(=...     gcr
# 69     Unspecified  c12n(ncc1C[C@@]1(C3=CC[C@]4(C([C@@H]3CCC1=C2)C...     gcr
# 32     Unspecified  C12(C(=O)NC(=O)NC1=O)O[C@@H]1C(=CC2)[C@@]2(C(=...     gcr
# 587    Unspecified  C12(C(=O)c3c(C1=O)cccc3)O[C@@H]1C(=CC2)[C@@]2(...     gcr
# 597    Unspecified  C12(C(=O)N(C(=O)N(C1=O)C)C)O[C@@H]1C(=CC2)[C@@...     gcr
# 6402             %  n1(c(cc(n1)CO[N+](=O)[O-])c1ccc(S(=O)(=O)C)cc1...    pgh2
# 11330            %         n1(c(cc(n1)CO)c1ccc(S(=O)(=O)C)cc1)C1CCCC1    pgh2
# 1383            mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr1
# 797             mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr2
# 8760            mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr2
# 1244            mg  [C@@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC...    esr2
# 11847           mg  [C@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC1...    esr1
# 1675            mg  [C@@]12([C@H]([C@H]3[C@@H](c4c(CC3)cc(cc4)O)CC...    esr1
# 11048            %             C=C([C@@H](NC(=O)c1occc1)c1ccccc1)CCCC    esr1
# 6270             %  c1(ccc(c(c1C)NC(=O)c1sc2c(c1)cccc2)F)c1n[nH]c(...    mk14
# 6401             %  n1(c(cc(n1)CO[N+](=O)[O-])c1ccc(S(=O)(=O)C)cc1...    pgh2
# 7928             %    C\1(=C\c2cc(c(OC(=O)C)cc2)OC)/c2c(c(ccn2)C)CCC1    pgh2
# 4176             %  [C@@]12(n3c4c5n([C@H](O1)C[C@H]([C@H]2OC)NC)c1...    cdk2
# 5740             %                C\1(=C\c2ccc(cc2)C)/c2ncc(cc2CCC1)C    pgh2
# 8596             %   n1c2/C(=C/c3cc(c(OC(=O)C)cc3)OC)/CCCc2cc2c1cccc2    pgh2
# 14677            %  c1cc(oc1c1ccc2c(c1)c(ncn2)Nc1ccc(c(c1)Cl)OCc1c...    egfr
# 4214             %  [nH]1cc(c2c1ncc(c2)c1cn(nc1)C1CCNCC1)c1cc(nc(n...     lck
# 4448             %  c1(ccc(cc1)NC(=O)Nc1n(nc(c1)C(C)(C)C)c1ccc(cc1...    mk14
# 4212             %  [nH]1cc(c2c1ncc(c2)c1cn(nc1)C1CCNCC1)c1nc(nc(c...     lck
# 2777             %  c1(ccc(cc1)NC(=O)Nc1n(nc(c1)C(C)(C)C)c1ccc(cc1...     lck
# 10025            %  c1(ccc2c(c1)c(c(cn2)C(=O)N)Nc1ccc(cc1)Br)C(=O)...    egfr
# 1942             %  C12=C[C@@H](C[C@@H]([C@@H]1[C@@H](CC[C@H]1OC(=...    hmdh
# ...            ...                                                ...     ...
# 6939            nM  C(=O)([C@@H]([C@H]([C@@H]([C@@H](NC(=O)OCc1ccc...   hivpr
# 3626            nM  [C@H](C(=O)N[C@H](C(=O)NCc1ncccc1)[C@H](CC)C)(...   hivpr
# 7003            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 6970            nM  C(=O)(N[C@H]([C@H]([C@@H](CC(=O)[C@H](NC(=O)OC...   hivpr
# 3624            nM  C(=O)(N[C@H]([C@H]([C@@H](CC(=O)[C@H](NC(=O)OC...   hivpr
# 3666            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)[C@...   hivpr
# 2731            nM                      c1(n(c2c(c1)cccc2)C)CN(CC#C)C    aofb
# 7013            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)NCc1ncccc1)C(C...   hivpr
# 7004            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 6252            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ncccc1)C(C...   hivpr
# 3600            nM  C(=O)([C@@H](NC(=O)[C@H](CC(=O)N)NC(=O)OCc1ccc...   hivpr
# 3680            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C...   hivpr
# 7014            nM  C(=O)([C@@H](NC(=O)[C@@H](NC(=O)CNC(=O)OCc1ccc...   hivpr
# 4827            nM                  c1c(ccc(c1)c1cc([nH]n1)c1ccccc1)C    aofb
# 609             nM                      S(=O)(=O)(c1sc(Sc2sccc2)cc1)N    cah2
# 590             nM              S(=O)(=O)(c1sc(S(=O)(=O)N)cc1)c1sccc1    cah2
# 4932            nM             c1(ccc2c(c1)cc([nH]2)CNCC#C)OCc1ccccc1    aofb
# 655             nM    S(=O)(=O)(c1ccc(N2C(=O)CCC2)c([N+](=O)[O-])c1)N    cah2
# 6907            nM  C(=O)(N[C@H](C(=O)OC)Cc1ccccc1)[C@@H](NC(=O)[C...   hivpr
# 3669            nM  C(=O)(N[C@H]([C@@H]([C@H]([C@@H](NC(=O)[C@@H](...   hivpr
# 3513            nM  N(C1c2c(C[C@H]1O)cccc2)C(=O)C(C[C@@H]([C@@H](N...   hivpr
# 3645            nM  C(=O)(N[C@H](C(=O)OC)C(C)C)[C@@H](NC(=O)[C@@H]...   hivpr
# 1809            nM                           S(=O)(=O)(c1ccc(NC)cc1)N    cah2
# 3636            nM  C(=O)(N[C@H]([C@H]([C@@H]([C@@H](NC(=O)OCc1ccc...   hivpr
# 6944            nM  C(=O)(N[C@H]([C@H]([C@H]([C@@H](NC(=O)[C@@H](N...   hivpr
# 387             nM  c1ccc2c(c1)nc(cc2)C(=O)N[C@H](C(=O)N[C@H]([C@@...   hivpr
# 7393            nM                             c1cc(ccc1S(=O)(=O)N)CC    cah2
# 1220            nM                          S(=O)(=O)(c1ccc(cc1)CCC)N    cah2
# 1247            nM                         S(=O)(=O)(c1ccc(cc1)CCCC)N    cah2
# 8770            nM                        S(=O)(=O)(c1ccc(cc1)CCCCC)N    cah2
#
# [487498 rows x 8 columns]

# %%
data.bioactivity_type.unique()
# Out:
# [Residual Activity, Ki, Kd, Inhibition, IC50, ..., Release, Activity remaining, cholesterol level, Suppression, PPB]
# Length: 450
# Categories (450, object): [Residual Activity, Ki, Kd, Inhibition, ..., Activity remaining, cholesterol level, Suppression, PPB]

# %%
data.units.unique()
# Out:
# [%, nM, ug.mL-1, mg.kg-1, M, ..., uM mg-1, mg dl-1, dpm, 10'4/s/M, nM/s]
# Length: 207
# Categories (207, object): [%, nM, ug.mL-1, mg.kg-1, ..., mg dl-1, dpm, 10'4/s/M, nM/s]

# %%
data.value.describe()
# Out:
# count    4.874980e+05
# mean     3.111819e+15
# std      1.748967e+18
# min     -2.360000e+02
# 25%      1.900000e+01
# 50%      2.238700e+02
# 75%      8.400000e+03
# max      1.202264e+21
# Name: value, dtype: float64
